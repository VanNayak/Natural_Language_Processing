# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
image = cv2.imread(r'C:\Users\DAI.STUDENTSDC\Desktop\6.NLP\Projects\images\cat_damaged.png')

# %%
# #If you want to display it with matplotlib (convert to RGB), do the following
# image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
# plt.imshow(image_rgb)
# plt.axis('off')  # Hide axes
# plt.show()

# %%
if image is None:
    print("Error: Image not loaded. Check the file path or format.")
else:
    cv2.imshow('Cat', image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
height, width, _ = image.shape

# %%
mask = np.zeros([height, width, 3], dtype=np.uint8)

# %%
for i in range(height):
    for j in range(width):
        if image[i,j].sum() == 0:
            mask[i, j] = [255, 255, 255]

# %%
cv2.imshow('Mask', mask)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
mask = cv2.cvtColor(mask, cv2.COLOR_BGR2GRAY)

# %%
# image inpainting
new_img = cv2.inpaint(image, mask, 3, cv2.INPAINT_NS)

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.title('Original Image')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 2)    
plt.title('Mask')    
plt.imshow(cv2.cvtColor(mask, cv2.COLOR_BGR2RGB))

plt.subplot(1, 3, 3)    
plt.title('Cleaned Image')    
plt.imshow(cv2.cvtColor(new_img, cv2.COLOR_BGR2RGB))
