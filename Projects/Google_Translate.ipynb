# %%
# !pip install goslate
# Out:
# ...
#   Using cached goslate-1.5.4.tar.gz (14 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Using cached futures-3.0.5.tar.gz (25 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for goslate: filename=goslate-1.5.4-py3-none-any.whl size=11628 sha256=36ec70870bdbab713d1cd479606a0d769780edb512897abdf0ef010d1c802712
#   Stored in directory: c:\users\dai.studentsdc\appdata\local\pip\cache\wheels\b6\48\7a\e7458e7a110a5525687dd17a52d3e42c157a8d22a2c4d5e840
# ...
#   Created wheel for futures: filename=futures-3.0.5-py3-none-any.whl size=14081 sha256=c0204ef3050f41d97ddf00ed7859185ccf40a9039288121c0e5204de69044b1b
#   Stored in directory: c:\users\dai.studentsdc\appdata\local\pip\cache\wheels\66\cb\37\51fe32ecb9068869196ce81111bdfe82e6ecb53c889362f81b
# Successfully built goslate futures
# ...

# %%
from goslate import Goslate

# %%
text = '''
Harvard University is a private Ivy League research university in Cambridge, Massachusetts, United States. Founded October 28, 1636, and named for its first benefactor, the Puritan clergyman John Harvard, it is the oldest institution of higher learning in the United States. Its influence, wealth, and rankings have made it one of the most prestigious universities in the world.[12]
Harvard was founded and authorized by the Massachusetts General Court, the governing legislature of colonial-era Massachusetts Bay Colony.[13] While never formally affiliated with any denomination, Harvard trained Congregational clergy until its curriculum and student body were gradually secularized in the 18th century.
By the 19th century, Harvard emerged as the most prominent academic and cultural institution among the Boston elite.[14][15] Following the American Civil War, under Harvard president Charles William Eliot's long tenure from 1869 to 1909, Harvard developed multiple professional schools, which transformed it into a modern research university. In 1900, Harvard co-founded the Association of American Universities.[16] James B. Conant led the university through the Great Depression and World War II, and liberalized admissions after the war.
The university has ten academic faculties and a faculty attached to Harvard Radcliffe Institute. The Faculty of Arts and Sciences offers study in a wide range of undergraduate and graduate academic disciplines, and other faculties offer graduate degrees, including professional degrees. Harvard has three campuses:[17] the main campus, a 209-acre (85 ha) in Cambridge centered on Harvard Yard; an adjoining campus immediately across Charles River in the Allston neighborhood of Boston; and the medical campus in Boston's Longwood Medical Area.[18] Harvard's endowment, valued at $50.7 billion, makes it the wealthiest academic institution in the world.[5][6] Harvard Library, with more than 20 million volumes, is the world's largest academic library.
'''

# %%
trans = Goslate()

# %%
# Traslate to Tamil
trans.translate(text=text, 
                target_language='ta')
# Out:
# 'ஹார்வர்ட் பல்கலைக்கழகம் அமெரிக்காவின் மாசசூசெட்ஸ், கேம்பிரிட்ஜில் உள்ள ஒரு தனியார் ஐவி லீக் ஆராய்ச்சி பல்கலைக்கழகம் ஆகும். அக்டோபர் 28, 1636 இல் நிறுவப்பட்டது, மேலும் அதன் முதல் பயனாளியான பியூரிட்டன் மதகுரு ஜான் ஹார்வர்டுக்கு பெயரிடப்பட்டது, இது அமெரிக்காவில் உயர் கற்றலின் மிகப் பழமையான நிறுவனமாகும். அதன் செல்வாக்கு, செல்வம் மற்றும் தரவரிசை ஆகியவை உலகின் மிகவும் மதிப்புமிக்க பல்கலைக்கழகங்களில் ஒன்றாகும். [12]\nஹார்வர்ட் காலனித்துவ கால மாசசூசெட்ஸ் விரிகுடா காலனியின் ஆளும் சட்டமன்றமான மாசசூசெட்ஸ் பொது நீதிமன்றத்தால் நிறுவப்பட்டு அங்கீகரிக்கப்பட்டது. [13] எந்தவொரு பிரிவினருடனும் முறையாக இணைக்கப்படாத நிலையில், ஹார்வர்ட் அதன் பாடத்திட்டம் மற்றும் மாணவர் அமைப்பு 18 ஆம் நூற்றாண்டில் படிப்படியாக மதச்சார்பற்றதாக இருக்கும் வரை சபை மதகுருக்களுக்கு பயிற்சி அளித்தார்.\n19 ஆம் நூற்றாண்டில், ஹார்வர்ட் போஸ்டன் உயரடுக்கினரிடையே மிக முக்கியமான கல்வி மற்றும் கலாச்சார நிறுவனமாக உருவெடுத்தார். [14] [15] அமெரிக்க உள்நாட்டுப் போரைத் தொடர்ந்து, ஹார்வர்ட் ஜனாதிபதி சார்லஸ் வில்லியம் எலியட்டின் 1869 முதல் 190
# ...

# %%
# Translate to Russian
trans.translate(text=text, 
                target_language='ru')

# %%
# Translate to French
trans.translate(text=text, 
                target_language='fr')

# %%
help(Goslate)

# %%
languages = Goslate().get_languages()

# %%
languages
# Out:
# {'ab': 'Abkhaz',
#  'ace': 'Acehnese',
#  'ach': 'Acholi',
#  'aa': 'Afar',
#  'af': 'Afrikaans',
#  'sq': 'Albanian',
#  'alz': 'Alur',
#  'am': 'Amharic',
#  'ar': 'Arabic',
#  'hy': 'Armenian',
#  'as': 'Assamese',
#  'av': 'Avar',
#  'awa': 'Awadhi',
#  'ay': 'Aymara',
#  'az': 'Azerbaijani',
#  'ban': 'Balinese',
#  'bal': 'Baluchi',
#  'bm': 'Bambara',
#  'bci': 'Baoulé',
#  'ba': 'Bashkir',
#  'eu': 'Basque',
#  'btx': 'Batak Karo',
#  'bts': 'Batak Simalungun',
#  'bbc': 'Batak Toba',
#  'be': 'Belarusian',
#  'bem': 'Bemba',
#  'bn': 'Bengali',
#  'bew': 'Betawi',
#  'bho': 'Bhojpuri',
#  'bik': 'Bikol',
#  'bs': 'Bosnian',
#  'br': 'Breton',
#  'bg': 'Bulgarian',
#  'bua': 'Buryat',
#  'yue': 'Cantonese',
#  'ca': 'Catalan',
#  'ceb': 'Cebuano',
#  'ch': 'Chamorro',
#  'ce': 'Chechen',
#  'ny': 'Chichewa',
#  'zh-CN': 'Chinese (Simplified)',
#  'chk': 'Chuukese',
#  'cv': 'Chuvash',
#  'co': 'Corsican',
#  'crh': 'Crimean Tatar (Cyrillic)',
# ...

# %%
len(languages)
# Out:
# 250
