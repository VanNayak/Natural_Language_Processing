# %% [markdown]
# Chunking is defined as the process of natural language processing used to identify parts of speech and short phrases present in a given sentence.
#
# Recalling our good old English grammar classes back in school, note that there are eight parts of speech namely the noun, verb, adjective, adverb, preposition, conjunction, pronoun, and interjection.
#
# Also in the above definition of chunking, short phrases refer to the phrases formed by including any of these part os speech.
#
# Chunking is used to get the required phrases from a word.

# %% [markdown]
# #### Install svgling

# %%
# !pip install svgling

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag, RegexpTagger
from nltk.chunk import RegexpParser

# %%
sent = 'It was good work done by him. An amazing play.'

# %%
# Create a chunk grammer with one regular expression rule:
'''According to the rule you created, your chunks:
Start with an optional(?) determiner('DT)
Can have any number(*) of adjectives(JJ)
End with a noun(<NN>)
'''

grammar = "NP: {<DT>?<JJ><NN>}"

# %%
grammar
# Out:
# 'NP: {<DT>?<JJ><NN>}'

# %%
import nltk
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')

chunk_parser = RegexpParser(grammar)
tags = pos_tag(word_tokenize(sent))
tree = chunk_parser.parse(tags)
tree
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('good', 'JJ'), ('work', 'NN')]), ('done', 'VBN'), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('.', '.')])

# %%
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('work', 'NN')]), ('done', 'VBN'), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('.', '.')])

# %%
# try with a variation in the grammar
sent = 'It was a good good work done by him. An amazing play.'
grammar = "NP: {<DT>?<JJ>*<NN>}"

chunk_parser = RegexpParser(grammar)
tags = pos_tag(word_tokenize(sent))
tree = chunk_parser.parse(tags)
tree
# Out:
# Tree('S', [('It', 'PRP'), ('was', 'VBD'), Tree('NP', [('a', 'DT'), ('good', 'JJ'), ('good', 'JJ'), ('work', 'NN')]), ('done', 'VBN'), ('by', 'IN'), ('him', 'PRP'), ('.', '.'), Tree('NP', [('An', 'DT'), ('amazing', 'JJ'), ('play', 'NN')]), ('.', '.')])

# %%
sent1 = 'They were watching the game. It was just thrilling.'

# %%
grammar1 = "VP: {<PRP><VBD>}"

# %%
chunk_parser = RegexpParser(grammar1)
tags = pos_tag(word_tokenize(sent1))
tree = chunk_parser.parse(tags)
tree
# Out:
# Tree('S', [Tree('VP', [('They', 'PRP'), ('were', 'VBD')]), ('watching', 'VBG'), ('the', 'DT'), ('game', 'NN'), ('.', '.'), Tree('VP', [('It', 'PRP'), ('was', 'VBD')]), ('just', 'RB'), ('thrilling', 'VBG'), ('.', '.')])

# %%
tree
# Out:
# Tree('S', [Tree('VP', [('They', 'PRP'), ('were', 'VBD')]), ('watching', 'VBG'), ('the', 'DT'), ('game', 'NN'), ('.', '.'), Tree('VP', [('It', 'PRP'), ('was', 'VBD')]), ('just', 'RB'), ('thrilling', 'VBG'), ('.', '.')])

# %%
sent2 = '''Exhausted from the long hike, we finally reached the summit, breathlessly adirming the  breathtaking panoramic view.'''

# %%
grammar2 = "VP: {<RB><VBG>}"

# %%
chunk_parser = RegexpParser(grammar2)
tags = pos_tag(word_tokenize(sent2))
tree = chunk_parser.parse(tags)
tree
# Out:
# Tree('S', [('Exhausted', 'VBN'), ('from', 'IN'), ('the', 'DT'), ('long', 'JJ'), ('hike', 'NN'), (',', ','), ('we', 'PRP'), ('finally', 'RB'), ('reached', 'VBD'), ('the', 'DT'), ('summit', 'NN'), (',', ','), Tree('VP', [('breathlessly', 'RB'), ('adirming', 'VBG')]), ('the', 'DT'), ('breathtaking', 'VBG'), ('panoramic', 'JJ'), ('view', 'NN'), ('.', '.')])
